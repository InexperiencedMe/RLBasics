# %%
import torch
import numpy as np
from mlagents_envs.environment import UnityEnvironment, BaseEnv, ActionTuple
from mlagents_envs.side_channel.environment_parameters_channel import EnvironmentParametersChannel
from mlagents_envs.side_channel.engine_configuration_channel import EngineConfigurationChannel
import random

environmentChannel = EnvironmentParametersChannel()
# engineChannel = EnvironmentParametersChannel() for now I can only have one channel at a time
env = UnityEnvironment(file_name=None, side_channels=[environmentChannel])
# channel.set_float_parameter("parameter_1", 2.0)
env.reset()

print(f"env.behavior_specs: {env.behavior_specs} So first element will be our behaviorName")
behaviorName = list(env.behavior_specs)[0]
specs = env.behavior_specs[behaviorName]
print(f"All specs: {specs}")

nContinuousActions = specs.action_spec.continuous_size
print(f"We have {nContinuousActions} continuous action size")
print(f"We have {specs.action_spec.discrete_size} branches of {specs.action_spec.discrete_branches} continuous action sizes respectively")

nEpisodes = 5
for i in range(1, nEpisodes + 1):
    done = False
    episodicReward = 0.0
    env.reset()
    decisionSteps, terminalSteps = env.get_steps(behaviorName)
    print(f"agent_id: {decisionSteps.agent_id}, and first element is {decisionSteps.agent_id[0]}")
    agentID = decisionSteps.agent_id[0] # I dont get that part yet
    state = decisionSteps.obs[agentID] # obs have shape 1, 1, 10 for now: nAgents, nStackedVectors, obsSize
    while not done:
        # gotta expand it so shape is not () but (1). Maybe not needed for more
        actionContinuous = np.expand_dims(np.random.randint(0, 2, dtype='int32'), 0).reshape(-1, 1)
        action = ActionTuple(continuous=actionContinuous)
        env.set_actions(behaviorName, action)
        env.step()
        decisionSteps, terminalSteps = env.get_steps(behaviorName)
        # print(f"decisionSteps: {decisionSteps[agentID]}")
        nextState = decisionSteps.obs[agentID]
        if agentID in terminalSteps:
            print(f"decisionSteps: {terminalSteps[agentID]}")
            done = True
            nextState = terminalSteps.obs[agentID]
            print(f"Total episodic reward: {episodicReward}")

        stepReward = decisionSteps.reward
        episodicReward += stepReward
        # print(f"Got reward: {stepReward}")
        state = nextState
env.close()
# Out:
# env.behavior_specs: <mlagents_envs.base_env.BehaviorMapping object at 0x000002000867A920> So first element will be our behaviorName
# All specs: BehaviorSpec(observation_specs=[ObservationSpec(shape=(10,), dimension_property=(<DimensionProperty.NONE: 1>,), observation_type=<ObservationType.DEFAULT: 0>, name='VectorSensor_size10')], action_spec=ActionSpec(continuous_size=1, discrete_branches=()))
# We have 1 continuous action size
# We have 0 branches of () continuous action sizes respectively
# agent_id: [0], and first element is 0
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-667.8989]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-5177.828]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# decisionSteps: TerminalStep(obs=[array([ 2.8531086e-01,  8.9141923e-01,  4.2479149e-01,  5.6321938e-02,
#         2.9499480e-04, -4.2644463e-02,  9.9750149e-01,  8.5831016e-01,
#         7.1035862e-01,  1.1994282e+00], dtype=float32)], reward=-0.14999999, interrupted=False, agent_id=0, group_id=0, group_reward=0.0)
# Total episodic reward: [-5856.2236]
# Got reward: [0.]
# agent_id: [0], and first element is 0
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# decisionSteps: TerminalStep(obs=[array([ 1.23870897e+00,  1.77786767e+00,  1.67718947e+00,  1.00508004e-01,
#         3.69332527e-04, -7.79434517e-02,  9.91878450e-01,  2.35753179e+00,
#        -1.05686045e+00,  3.14266515e+00], dtype=float32)], reward=0.0, interrupted=False, agent_id=0, group_id=0, group_reward=0.0)
# Total episodic reward: [-3.3000007]
# Got reward: [0.]
# agent_id: [0], and first element is 0
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-42753.277]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# decisionSteps: TerminalStep(obs=[array([ 7.5901289e+00, -1.7233686e+01,  1.0733056e+01,  4.8774359e-01,
#        -1.5280514e-03, -3.4414667e-01,  8.0228859e-01,  2.9228845e+00,
#        -1.7456781e+01,  4.1469374e+00], dtype=float32)], reward=0.0, interrupted=False, agent_id=0, group_id=0, group_reward=0.0)
# Total episodic reward: [-42761.465]
# Got reward: [0.]
# agent_id: [0], and first element is 0
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-49667.273]
# Got reward: [-0.14999999]
# Got reward: [-30029.916]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-8646.451]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# Got reward: [0.]
# Got reward: [-0.14999999]
# Got reward: [-0.14999999]
# decisionSteps: TerminalStep(obs=[array([ 0.5833312 ,  0.15017185,  0.8955072 ,  0.6579412 , -0.25529534,
#        -0.25909966, -0.6593975 ,  0.03585878, -0.01176584, -0.04116632],
#       dtype=float32)], reward=0.0, interrupted=False, agent_id=0, group_id=0, group_reward=0.0)
# Total episodic reward: [-88351.22]
# Got reward: [0.]
# agent_id: [0], and first element is 0
# decisionSteps: TerminalStep(obs=[array([-1.56843662e-03,  1.98296976e+00,  1.14020705e-03,  6.60552859e-01,
#        -2.59649962e-01, -2.54841298e-01, -6.56740248e-01, -1.13314606e-01,
#        -6.23677313e-01,  9.72433463e-02], dtype=float32)], reward=-0.14999999, interrupted=False, agent_id=0, group_id=0, group_reward=0.0)
# Total episodic reward: 0.0
# Got reward: [0.]
